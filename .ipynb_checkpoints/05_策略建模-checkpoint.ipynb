# %% [markdown]
# # 1. 建立训练集
# ## 1.1
# ### 1.1.1 策略和模型
# 不同的事情
#
# ## 1.2 输入特征的选择
# 1. 选择特征是Quant对问题的一种理解
# 2. 不同人有不同理念
# 3. 不同理念会造成不同的feature选择
# 4. pipeline相同
#
# ## 1.3 选择特征的主流流程和方法
#
# ## 1.4 对好的特征进行自动筛选
#
# ## 1.5 基本方法和原则
# 1. 特征选择取决于个人对问题的理解
#
# ## 1.6 常见特征
# 1. time lags ==> create_lagged_series(起始时间，终止时间，时间窗格) ==> 时间t向前看5个点，10个点，
# 2. EOD时刻的开盘价的比率
# 3. CCI ==> CCI的定义 ===> 技术分析
# 4. EVM
# 5. MA
# 6. 卡曼滤波器
# 7. ROC
# 8. BOLL
# 9. 50-300个feature DataFrame数据结构
# 10. TF/IDF
# 11. 指标是否达到要求
#
# ## 1.7 建立训练集
# 1. 可能会需要GPU，如果用sklearn，能够并行的算法有个参数n_jobs，默认-1是全配
#
# ## 1.8 随机森林 ==> 基于梯度xqboost
# 1. 随机森林，基于决策树的概念 ===> 复习决策树
# 2. 集成学习 ==> 每种关注的点不同 ==> 这样就可以更加高效
# 3. XGBOOST(集成学习的方式) ==> GBDT ==> 森林的树木和深度 ==> 线性串行的 ==> blending and stacking 集成学习的方法 ==> 只好不坏 ==> 无风险提高
# 4. 宏方法是一种思考的方式
# 5. 基于梯度的boosting tree
# 6. 使用暴力枚举和贝叶斯方法(解析一个banid的问题) ==> 交叉验证的方式
#
# ## 1.9 逻辑回归
#
# ## 1.10 SVM和SVR
#
# ## 1.11 ANN
# 1. ReLU和tanh激活函数
# 2. keras ==> 封装的库 ==> 基于TF和THEAO实现的
# 3. MLP ==> BP是通过链式求导的法则，减少了大量重复运算
# 4. 损失函数 ==> cross entropy(分类) ==> MSE(回归)
# 5. dropout ==> 取0.5 ==> 做了集成学习
# 6. SGD(随机梯度下降)/ADAM/AGADELTA
# 7. 求矩阵的逆矩阵
# 8. 交叉验证
# 9. box plot
#
# ------
# # 2. 特征选择
# 1. 子集选择 ==> R平方值(最大值)/AIC/BIC/RSS ==> 暴力选择/贪心算法
# 2. shrinkage ==> LASSO
# 3. 降维 ==> 降维的方法
#
# ------
# # 3. 遗传算法
# 1. 最优算法 ==> 求最佳的投资组合
# 2. 种群
# 3. 基因 ==> 变异(R2的值)
# 4. 适合函数
# 5. 多样性 ==> Entropy熵值
# 6. 遗传算法是一个优化问题 ==> 求极值问题
# 7. 遗传算法选股 ==>
# 8. 缺点
# 9. PPOS ==> 子集选择
# ------
# # 4. ANN神经网络
# ## 4.1 感知器
#
#
# ## 4.2 BP算法
#
# ------
# # 5. RNN ==> 循环神经网络
#
#
# ------
# # 6. 递归神经网络
#
#
# ------
# # 7. LSTM
# RMSPROP()算法
# ------
# karl sims ==> 关于遗传算法的动画模型
