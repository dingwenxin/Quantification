# %% [markdown]
# # 1. 入门
# **关键点：2h**

# %% [markdown]
# ## 1.1 算法交易综述
# 1. 所谓算法交易，利用自动化平台，执行预先设置的一系列规则完成交易行为
#
# ### 1.1.1 优势
# 1. 历史数据评估
# 2. 执行高效
# 3. 无主观情绪输入
# 4. 可度量评价
# 5. 交易频率
#
# ### 1.1.2 劣势
# 1. 成本
# 2. 技巧
#
# ### 1.1.3 交易流程
# 基于某种平台：
# 1. 提出假设
# 2. 建立模型
# 3. 回测验证
# 4. 执行交易
#
# ## 1.2 交易策略的来源
# **尽量找英文的**
# 1. 市场微观结构研究
# 2. 基金结构套利
# 3. 机器学习/人工智能
#
# ```
# ORDER BOOK: ===>没听懂？以买家撮合
#
# 买的价格：从高往低排
# 卖的价格：从低往高排
#
# 券商以买家最高和卖价的最低进行交易
# ```
#
# ## 1.3 机器学习流程
# 输入==> 函数(模型) ==> 输出，机器学习4个门派：
# 1. 联结主义==>神经网络
# 2. 符号主义==>可解释性
# 3. 频率主义
# 4. 贝叶斯主义
#
# ## 1.4 AI历史
#
# ## 1.5 机器学习
# 1. 数据
# 2. 模型和损失函数
# 3. 优化算法==>寻找损失函数的极值点
#
# ```
# 统计学和机器学习(数据驱动的统计学)
# ```
#
# ## 1.6 Machine Learning and Trading
# 1. limit order book modeling
# 2. 基于价格的分类模型===> 买卖，持有
# 3. 基于文本分类 ===> 基于新闻，通过自然语言处理===>输入文本，输出最后可能涨的股票 ===> 用来做风控
# 4. 强化学习
#
# ## 1.7 成功要点
# 1. 好的模型和有效的算法
# 2. 好的算力
# 3. 高质量的数据===>好的输入特征
# 4. 好的平台(keras/tensorflow/sklearn)
#
# ## 1.8 深度学习
# 1. CNN ===> 空间上的卷积神经网络
# 2. LSTM ===> 时间上的 ===> HMM 马科夫模型
#
# ## 1.9 强化学习 ==> 高阶级的ML
#
# ## 1.10 自然语言处理 ==> word2vec
# 新闻，对价格影响；文本==>编码(非监督学习)===>输入向量X==>ML==>分类 ==> 选股
#
# ## 1.11 交易模型
# 1. 特征工程===>根据经验来选择indicator，放进200个
# 2. 特征选择===>从200个里面选择有用的组合
#
# ## 1.12 交易策略评估
# 1. 策略基本假设
# 2. sharp ratio
# 3. 杠杆
# 4. 频率
# 5. 风险
# 6. W/L
# 7. 模型复杂度 ==> VC维度
# 8. 最大亏损
# 9. Benchmarking
#
# ## 1.13 回测
# 1. 将交易策略在历史数据中进行合理验证的过程
# 2. 科学回测十分重要==>大部分人死在回测上
#
# ## 1.14 回测意义
# 1. 策略筛选
# 2. 策略优化
# 3. 策略验证
#
# ## 1.15 错误回测方法==>回测结果不错，实盘不尽人意
# 1. 乐观主义偏差
# 2. **时间旅行**==>程序bug，分好训练集，验证集(新数据)，测试集(新数据)
# 3. 幸存者误差===>要选很多公司
#
# ## 1.16 工具和语言
# 1. python
# 2. sklearn
# 3. pandas===>一定要学pandas
#
# ## 1.17 量化交易：从工程的角度==>事件驱动型
# 主要模块：
# 1. Event ==> 事件
# 2. Event Queue ==> 事件队列
# 3. DataHandler ==> 处理数据
# 4. Strategy ==> 处理策略 ==> (model signal) ==> 需要不断更新
# 5. Portfolio ==> 投资组合 ==> 管家类
# 6. ExecutionHandler ==> 执行处理
# 7. Backtest ==> 回测

# %%
while True:
    # 监听事件，放到队列
    new_event = get_new_event() 
    
    if new_event.someting == "whaterver":
        do_something()
    if new_event.someting == "all right"：
        do_something()
        
    tick(50) # wait 50 milliseconds， heartbeat
