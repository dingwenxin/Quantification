# %% [markdown]
# # 3. 交易实战 ==> learn python the hard way
# ## 1. 数据获得与存储 ===> outline
# ### 1.1 建立数据库的意义
# 1. 建模
# - 模型建立
# - 模型评估
# - 模型回测
# - 风险控制
#
# 2. 交易
#
# 目的：能存，能取
#
#
# ### 1.2 数据获取
# http://tushare.org/index.html
# Yahoo Finance - http://finance.yahoo.com; ==> 课程讲授
# Google Finance; QuantQuote; EODData
#
# ### 1.3 存储方式
# - CSV
# - NoSQL
# - SQL
# - 其他
#
# ### 1.4 数据格式
# - 交易信息
# - 数据来源
# - Ticker/symbol
# - 价格
# - 企业行为(stock splits/dividend adjustments)
# - 国家假日
#
# ### 1.5 容易出错的地方
# - 企业行为
# - spikes：用spike filter ==> 滤波器
# - 缺失数据 ==> pandas处理
#
# ### 1.6 搭建MySQL数据库 ===> 服务器
# 1. 安装MySQL数据库
# 2. 创建用户名
# 3. 创建数据库和表
#
# ### 1.7 设计股票EOD数据的表
# 1. Exchange
# 2. DataVendor ==> 根据特定的网站来确定一个数据来源
# 3. Symbol
# 4. DailyPrice ==> 最重要的
#
# ### 1.8 python同数据库连接
# ```
# sudo apt-get install libmysqlclinet-dev
# pip install mysqlclient
#
# ```
#
# ### 1.9 任务 ===> list of s&p 500，先从维基百科拿到相关程序
# 1. 从a处获得股票的symbol
# 2. 从b处获得响应的价格
# 3. 存在某处
# 4. 将来随时读取
#
# insert_symbols.py
# beautiful_soap
# Price_retrivel.py
# Retrieving_Data.py ==> 主函数
#
# pandas.io.data as web ==> 使用web.DataReader() ==> 直接用pandas来获得需要的数据
#
# Quandl_data.py ==> 注册以后每天请求500下，不注册的请求50下
#
# ### 1.10 作业
# 1. 利用tushare的api，获取trading.html的数据，存在本地，hint:http://tushare.org/storing.html ==> 会使用api
# 2. 对沪深300股票做聚类 ==> 二维嵌入
# http://scikit-learn.org/stable/auto_examples/applications/plot_stock_market.html#stock-market ==> 例子 ==> 边是两个股票的相似度
#
# ------
# # 2. 时间序列分析实战
# Mean Reversion and Ornstein-Uhenbeck process ==> tushare文本处理能力还可以 ==> 每只股票大部分是**随机游走**，也就是不好预测 ==> 平稳的随机过程 ==> 建立一个投资组合 ==> 投资组合是固定
#
# ## 2.1 ADF Test ==> 判读是不是平稳的 ==> statmodels ==> adfuller，函数
#
# ## 2.2 Hurst 判断 ==> 函数自己写
#
# ## 2.3 作业
# mean-reverting对沪深300测试
#
# ## 2.4 从单一股票到投资组合
# 1. cadf.py
# 2. scatter plot ==> 可视化
# 3. p-value t-statistics ==> 协整关系的pairs
#
# ------
# # 3. Machine Learning: A different Approach
# 1. Y = f(x) + e
# 2. 逻辑回归
# 3. SVM
# 4. 随机森林
# 5. LSTM(高级RNN) ==> HMM ==> 动态线性系统 ===> sk-learn库 ==> LASSO 和 OLS
# 6. keras
# 7. 正则化对模型，归一化对数据来言
